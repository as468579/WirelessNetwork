# %%
import numpy as np
import matplotlib.image as mpimg # mpimg 用於讀取圖片
import matplotlib.pyplot as plt
import cv2

image = cv2.imread("IMG_6079.JPG")
# image = cv2.imread("image.jpeg")
image = cv2.resize(image, (image.shape[1] // 2, image.shape[0] // 2))

blue = image[:, :, 0]
green = image[:, :, 1]
red = image[:, :, 2]

tmp = np.zeros(image.shape, dtype = np.uint8)

tmp[:, :, 0] = blue
# tmp[:, :, 1] = green
# tmp[:, :, 2] = red

cv2.imshow('orig', tmp)
cv2.waitKey(0)


tmp = np.zeros(image.shape, dtype = np.uint8)
# ret2,gray = cv2.threshold(gray,180,255,cv2.THRESH_BINARY)
# ret2,gray = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
tmp[:, :, 0] = blue
tmp[:, :, 1] = green
# tmp[:, :, 2] = red
# cv2.imwrite("back_1080_red_15950.png", tmp)
# cv2.imwrite("back_1080_green_15950.png", green)

cv2.imshow('test', tmp)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
blue = np.rot90(blue)
green = np.rot90(green)
red = np.rot90(red)

avg_b = np.mean(blue, axis = 1)
avg_g = np.mean(green, axis = 1)
avg_r = np.mean(red, axis = 1)
print(len(avg_b))
print(len(avg_g))
print(len(avg_r))



plt.plot(avg_b - avg_r, "b")
plt.plot(avg_g - avg_b, "g")
plt.plot(avg_g - avg_r, "r")
# plt.plot(avg_b, "b")
# plt.plot(avg_g, "g")
# plt.plot(avg_r, "r")
# Out:
# 540
# 540
# 540

# %%
g : 44000 r, b : 22000
# Out:
#   File "<ipython-input-56-f66bbad851aa>", line 1
#     g : 44000 r, b : 22000
#               ^
# SyntaxError: invalid syntax

# %%
1920/1080
# Out:
# 1.7777777777777777

# %%
4032/3024
# Out:
# 1.3333333333333333

# %%
sample_rate = 88000

# %%
1/1.11e-5/2
# Out:
# 45045.045045045044
